# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics

# %%
val = [10, 10, 10, 10, 0]
pred = [10, 10, 10, 10, 100]

# %%
sklearn.metrics.mean_absolute_error(val, pred)
# Out:
# 20.0

# %%
sklearn.metrics.mean_squared_error(val, pred)
# Out:
# 2000.0

# %%
sklearn.metrics.root_mean_squared_error(val, pred)
# Out:
# 44.721359549995796
